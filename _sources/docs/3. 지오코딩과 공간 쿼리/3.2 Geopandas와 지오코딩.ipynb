# %% [markdown]
# # Geopandas와 지오코딩

# %% [markdown]
# ---

# %% [markdown]
# &emsp;Geopandas는 [geopy](https://geopy.readthedocs.io/en/stable/) 라이브러리를 통해 지오코딩(geocoding)을 지원합니다. Geopandas의 [`geopandas.tools.geocode()`](https://geopandas.org/en/stable/docs/user_guide/geocoding.html) 함수를 사용하기 위해서는 geopy 라이브러리가 설치되어야 합니다. `geocode()`는 주소(문자열; `string`)로 구성된 리스트(`list`) 또는 `pandas.Series`를 입력값으로 받아 주소와 점 도형(point geometry)으로 구성된 `GeoDataFrame`을 반환합니다.
#
# &emsp;지오코딩할 주소를 세미콜론(`;`)으로 구분된 텍스트 파일로 만들어 `addresses.txt`로 저장합니다. `addresses.txt` 파일은 아래와 같이 구성되어 있습니다.

# %% [markdown]
# 지점;지점주소
# 400;서울특별시 강남구일원동 580탄천 물재생센터
# 401;서울특별시 서초구서초동 1416번지서초 IC
# 402;서울특별시 강동구고덕로 183서울종합직업전문학교
# 403;서울특별시 송파구올림픽로 240롯데월드
# . . .

# %% [markdown]
# &emsp;Pandas 라이브러리를 이용해 `addresses.txt` 데이터를 읽어오겠습니다. 아래에서 보시다시피, 각 행에 대한 `지점` 열과 주소가 입력된 `지점주소` 열이 있습니다.

# %%
import pathlib
import pandas as pd

NOTEBOOK_PATH = pathlib.Path().resolve()
DATA_DIRECTORY = NOTEBOOK_PATH / "data"

addresses = pd.read_csv(DATA_DIRECTORY / "addresses.txt", sep=";")
addresses
# Out:
#      지점                              지점주소
# 0   400                 서울특별시 강남구 일원동 580
# 1   401             서울특별시 서초구 서초동 1416번지
# 2   402               서울특별시 강동구 고덕로 183
# 3   403              서울특별시 송파구 올림픽로 240
# 4   404               서울특별시 강서구 양천로 201
# 5   405              서울특별시 양천구 목동동로 298
# 6   406              서울특별시 도봉구 시루봉로 173
# 7   407  서울특별시 노원구 공릉동 사서함 230-3호 사서함 77호
# 8   408             서울특별시 동대문구 서울시립대로 163
# 9   409             서울특별시 중랑구 면목로57길 32
# 10  410             서울특별시 동작구 여의대방로16길 61
# 11  411              서울특별시 마포구 창전동 산1-75
# 12  412               서울특별시 서대문구 연세로 50
# 13  413           서울특별시 광진구 자양2동 680-67
# 14  414                 서울특별시 성북구 정릉로 77
# 15  415               서울특별시 용산구 이촌로 255
# 16  416               서울특별시 은평구 진관동 산26
# 17  417           서울특별시 금천구 시흥대로104길 31
# 18  418              서울특별시 영등포구 여의동로 280
# 19  419               서울특별시 중구 소파로 83  \t
# 20  421               서울특별시 성동구 서울숲길 18
# 21  422                 서울특별시 종로구 북악산로267
# 22  423               서울특별시 구로구 부일로 893
# 23  424             서울특별시 강북구 도봉로89길 13
# 24  425     서울특별시 관악구 남현동 산100-1420003호
# 25  509                  서울특별시 관악구 관악로 1
# 26  510           서울특별시 영등포구 국회대로53길 20
# 27  889               서울특별시 동작구 현충로 210

# %% [markdown]
# ## Photon을 사용한 지오코딩

# %% [markdown]
# &emsp;*[Photon](https://photon.komoot.io/)* 지오코더(geocoder)를 사용해 위의 `지점주소`들을 지오코딩 하겠습니다. Photon은 OpenStreetMap 데이터를 사용하는 지오코더 서비스 입니다. Geopandas의 `geocode()` 함수는 기본적으로 photon에 기반한 지오코딩을 지원합니다.

# %% [markdown]
# ```{note}
# &emsp;[Nominatim 이용 약관](https://operations.osmfoundation.org/policies/nominatim/)에 따라, 사용자는 1초당 1회보다 많이 API 요청을 보낼 수 없습니다. 그리고 API 요청 시 **`user-agent`**에 대한 정보를 필수적으로 입력해야 합니다.
#
# &emsp;주소를 조회하는 작업은 꽤 많은 연산을 필요로 하는 데이터베이스 작업입니다. 이러한 이유 때문에 공용 및 무료 Nominatim API를 통해 응답을 얻기까지 때때로 오랜 시간이 소요될 수 있습니다. 따라서, 여기에서는 파라미터 `timeout=10`을 추가하여 API 응답을 최대 10초 동안 기다리도록 설정합니다.
# ```

# %%
import geopandas as gpd

geocoded_addresses = gpd.tools.geocode(addresses["지점주소"], # 지오코딩할 주소
                                       provider="photon", # 지오코더
                                       user_agent="test", # user-agent 설정 필수 (Nominatim)
                                       timeout=10
                                      )
geocoded_addresses
# Out:
#                       geometry  \
# 0   POINT (127.08775 37.47971)
# 1   POINT (127.02191 37.47954)
# 2   POINT (127.14557 37.55604)
# 3   POINT (127.09824 37.51150)
# 4   POINT (126.81027 37.57468)
# 5   POINT (126.87355 37.52290)
# 6   POINT (127.02772 37.65291)
# 7                  POINT EMPTY
# 8   POINT (127.05918 37.58302)
# 9   POINT (127.08852 37.59191)
# 10  POINT (126.92597 37.49854)
# 11                 POINT EMPTY
# 12  POINT (126.94038 37.56230)
# 13                 POINT EMPTY
# 14  POINT (126.99594 37.61029)
# 15                 POINT EMPTY
# 16  POINT (126.91181 37.63268)
# 17  POINT (126.90003 37.46524)
# 18  POINT (126.93841 37.52578)
# 19  POINT (126.98384 37.55617)
# 20  POINT (127.06943 37.55290)
# 21  POINT (126.98893 37.57054)
# 22                 POINT EMPTY
# 23  POINT (127.02682 37.60338)
# 24                 POINT EMPTY
# 25  POINT (126.95671 37.48677)
# 26  POINT (126.92153 37.52963)
# 27  POINT (126.97018 37.49665)
#
#                                               address
# 0      서울특별시아동학대예방센터, 광평로34길, 06352, 광평로34길, 서울, 대한민국
# 1   서울특별시데이터센터, 남부순환로340길, 06724, 남부순환로340길, 서울, 대한민국
# 2      서울특별시 동부기술교육원, 183, 고덕로, 05235, 고덕로, 고덕동, 대한민국
# 3             롯데월드, 240, 올림픽로, 05554, 올림픽로, 잠실동, 대한민국
# 4          월드메르디앙 201동, 양천로1길, 07602, 양천로1길, 서울, 대한민국
# 5          405-298, 목동동로12길, 08005, 목동동로12길, 서울, 대한민국
# 6          서울특별시립도봉도서관, 시루봉로, 01375, 시루봉로, 쌍문4동, 대한민국
# 7                                                None
# 8    서울시립대학교, 163, 서울시립대로, 02504, 서울시립대로, 서울특별시, 대한민국
# 9            32, 면목로84길, 02162, 면목로84길, 서울시 중랑구, 대한민국
# 10         동작보라매자이더포레스트, 서울특별시 동작구 여의대방로22길 121, 대한민국
# 11                                               None
# 12         세브란스병원, 50-1, 연세로, 03722, 연세로, 서울특별시, 대한민국
# 13                                               None
# 14  국민대학교우편취급국, 77 종합복지관 2층, 정릉로, 02707, 정릉로, 정릉동,...
# 15                                               None
# 16             서울특별시 소방학교, 통일로, 03312, 통일로, 진관동, 대한민국
# 17  서울독산초등학교, 31, 시흥대로104길, 08618, 시흥대로104길, 금천구, ...
# 18       여의도 이랜드크루즈, 280, 여의동로, 07337, 여의동로, 서울, 대한민국
# 19                     83, 소파로, 04630, 소파로, 예장동, 대한민국
# 20                   서울숲아이파크, 서울특별시 성동구 동일로 237, 대한민국
# 21        종로경찰서, 종로17길, 03140, 종로17길, 서울특별시 종로구, 대한민국
# 22                                               None
# 23  강북세일학원, 13, 정릉로48길, 02801, 정릉로48길, 서울특별시 성북구, ...
# 24                                               None
# 25  서울봉천동우체국, 249-1, 관악로, 08727, 관악로, 서울특별시 관악구, 대한민국
# 26  맨하탄21리빙텔, 20, 국회대로74길, 07238, 국회대로74길, 서울특별시 영...
# 27           김대중대통령묘소, 210, 현충로, 06984, 현충로, 서울, 대한민국

# %% [markdown]
# &emsp;그 결과, `지점주소`를 지오코딩하여 얻은 좌표 `geometry`열과 `address` 열이 포함된 `GeoDataFrame`을 얻었습니다. 이 중 `geometry`열은 지리공간 데이터 형식인 `shapely.geometry.Point`로 구성됩니다.
#
# &emsp;기존의 입력 데이터셋인 `addresses`와 결합하기 위해 pandas의 [조인(join)](https://pandas.pydata.org/docs/user_guide/merging.html) 기능을 사용할 수 있습니다.

# %% [markdown]
# ## 데이터프레임 조인 (DataFrame Join)

# %% [markdown]
# &emsp;두 개 이상의 데이터프레임 또는 테이블의 데이터를 조인하는 작업은 (공간)데이터 분석 워크플로(workflow)에서 대다수의 경우 수행됩니다. 이전 단원의 내용을 떠올려 보겠습니다. 테이블들을 결합하기 위해 공통되는 <b>키(key)</b> 속성이 있는 경우, `merge()` 함수를 사용하여 간단하게 수행할 수 있습니다.
#
# &emsp;그러나 때로는 <b>인덱스(index)</b>에 기반하여 두 데이터프레임을 조인하는 것이 유용합니다. 이 경우, 두 데이터프레임은 **동일한 수의 행**을 가져야 하며, **동일한 인덱스를 공유**해야 합니다.
#
# &emsp;여기에서는 원본 데이터프레임인 `addresses`와 지오코딩 결과인 `geocoded_addresses`의 레코드 순서가 동일하므로, 인덱스에 기반한 조인 방식을 사용하여 두 개의 데이터프레임을 행별로 조인합니다. 참고로 `join()` 함수는 아무런 설정을 하지 않을 경우, 인덱스에 기반하여 두 개의 데이터프레임을 조인합니다.
#
# &emsp;새로운 데이터프레임인 `geocoded_addresses_with_id`은 원본 데이터프레임에 있었던 모든 열과 지오코딩 결과인 `geometry` 열, `address` 열도 포함되어 있습니다.

# %%
geocoded_addresses_with_id = geocoded_addresses.join(addresses)
geocoded_addresses_with_id
# Out:
#                       geometry  \
# 0   POINT (127.08775 37.47971)
# 1   POINT (127.02191 37.47954)
# 2   POINT (127.14557 37.55604)
# 3   POINT (127.09824 37.51150)
# 4   POINT (126.81027 37.57468)
# 5   POINT (126.87355 37.52290)
# 6   POINT (127.02772 37.65291)
# 7                  POINT EMPTY
# 8   POINT (127.05918 37.58302)
# 9   POINT (127.08852 37.59191)
# 10  POINT (126.92597 37.49854)
# 11                 POINT EMPTY
# 12  POINT (126.94038 37.56230)
# 13                 POINT EMPTY
# 14  POINT (126.99594 37.61029)
# 15                 POINT EMPTY
# 16  POINT (126.91181 37.63268)
# 17  POINT (126.90003 37.46524)
# 18  POINT (126.93841 37.52578)
# 19  POINT (126.98384 37.55617)
# 20  POINT (127.06943 37.55290)
# 21  POINT (126.98893 37.57054)
# 22                 POINT EMPTY
# 23  POINT (127.02682 37.60338)
# 24                 POINT EMPTY
# 25  POINT (126.95671 37.48677)
# 26  POINT (126.92153 37.52963)
# 27  POINT (126.97018 37.49665)
#
#                                               address   지점  \
# 0      서울특별시아동학대예방센터, 광평로34길, 06352, 광평로34길, 서울, 대한민국  400
# 1   서울특별시데이터센터, 남부순환로340길, 06724, 남부순환로340길, 서울, 대한민국  401
# 2      서울특별시 동부기술교육원, 183, 고덕로, 05235, 고덕로, 고덕동, 대한민국  402
# 3             롯데월드, 240, 올림픽로, 05554, 올림픽로, 잠실동, 대한민국  403
# 4          월드메르디앙 201동, 양천로1길, 07602, 양천로1길, 서울, 대한민국  404
# 5          405-298, 목동동로12길, 08005, 목동동로12길, 서울, 대한민국  405
# 6          서울특별시립도봉도서관, 시루봉로, 01375, 시루봉로, 쌍문4동, 대한민국  406
# 7                                                None  407
# 8    서울시립대학교, 163, 서울시립대로, 02504, 서울시립대로, 서울특별시, 대한민국  408
# 9            32, 면목로84길, 02162, 면목로84길, 서울시 중랑구, 대한민국  409
# 10         동작보라매자이더포레스트, 서울특별시 동작구 여의대방로22길 121, 대한민국  410
# 11                                               None  411
# 12         세브란스병원, 50-1, 연세로, 03722, 연세로, 서울특별시, 대한민국  412
# 13                                               None  413
# 14  국민대학교우편취급국, 77 종합복지관 2층, 정릉로, 02707, 정릉로, 정릉동,...  414
# 15                                               None  415
# 16             서울특별시 소방학교, 통일로, 03312, 통일로, 진관동, 대한민국  416
# 17  서울독산초등학교, 31, 시흥대로104길, 08618, 시흥대로104길, 금천구, ...  417
# 18       여의도 이랜드크루즈, 280, 여의동로, 07337, 여의동로, 서울, 대한민국  418
# 19                     83, 소파로, 04630, 소파로, 예장동, 대한민국  419
# 20                   서울숲아이파크, 서울특별시 성동구 동일로 237, 대한민국  421
# 21        종로경찰서, 종로17길, 03140, 종로17길, 서울특별시 종로구, 대한민국  422
# 22                                               None  423
# 23  강북세일학원, 13, 정릉로48길, 02801, 정릉로48길, 서울특별시 성북구, ...  424
# 24                                               None  425
# 25  서울봉천동우체국, 249-1, 관악로, 08727, 관악로, 서울특별시 관악구, 대한민국  509
# 26  맨하탄21리빙텔, 20, 국회대로74길, 07238, 국회대로74길, 서울특별시 영...  510
# 27           김대중대통령묘소, 210, 현충로, 06984, 현충로, 서울, 대한민국  889
#
#                                 지점주소
# 0                  서울특별시 강남구 일원동 580
# 1              서울특별시 서초구 서초동 1416번지
# 2                서울특별시 강동구 고덕로 183
# 3               서울특별시 송파구 올림픽로 240
# 4                서울특별시 강서구 양천로 201
# 5               서울특별시 양천구 목동동로 298
# 6               서울특별시 도봉구 시루봉로 173
# 7   서울특별시 노원구 공릉동 사서함 230-3호 사서함 77호
# 8              서울특별시 동대문구 서울시립대로 163
# 9              서울특별시 중랑구 면목로57길 32
# 10             서울특별시 동작구 여의대방로16길 61
# 11              서울특별시 마포구 창전동 산1-75
# 12               서울특별시 서대문구 연세로 50
# 13           서울특별시 광진구 자양2동 680-67
# 14                 서울특별시 성북구 정릉로 77
# 15               서울특별시 용산구 이촌로 255
# 16               서울특별시 은평구 진관동 산26
# 17           서울특별시 금천구 시흥대로104길 31
# 18              서울특별시 영등포구 여의동로 280
# 19               서울특별시 중구 소파로 83  \t
# 20               서울특별시 성동구 서울숲길 18
# 21                 서울특별시 종로구 북악산로267
# 22               서울특별시 구로구 부일로 893
# 23             서울특별시 강북구 도봉로89길 13
# 24     서울특별시 관악구 남현동 산100-1420003호
# 25                  서울특별시 관악구 관악로 1
# 26           서울특별시 영등포구 국회대로53길 20
# 27               서울특별시 동작구 현충로 210

# %% [markdown]
# &emsp;`join()` 함수 출력(output)의 데이터 타입은 `geopandas.GeoDataFrame` 입니다.

# %%
type(geocoded_addresses_with_id)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ```{note}
# &emsp;`geocoded_addresses.join(addresses)`와 반대로 `address.join(geocoded_addresses)`처럼 조인하는 경우, 출력 데이터 타입은 `geopandas.GeoDataFrame`이 아닌 `pandas.DataFrame`이 됩니다.
# ```

# %% [markdown]
# &emsp;마지막으로 새 데이터프레임을 *GeoPackage* 형식(format)의 지리공간 파일로 간단하게 저장할 수 있습니다.

# %%
geocoded_addresses_with_id.to_file(DATA_DIRECTORY / "addresses.gpkg")

# %% [markdown]
# ---

# %% [markdown]
# ```{raw} html
# <script src="https://utteranc.es/client.js"
#         repo="Kwan-Gu/geospatial_analysis"
#         issue-term="pathname"
#         theme="preferred-color-scheme"
#         crossorigin="anonymous"
#         async>
# </script>
# ```
